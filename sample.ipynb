# %%
a =1 
b = 1.0
d = True
print(type(a))
print(type(b))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
students = ["Hermione", "Harry", "Ron", "Anish"]
for student in students:
    print(student)
# Out:
# Hermione
# Harry
# Ron
# Anish

# %%
students = [
    {"name": "Hermione", "house": "Gryffindor", "patronus": "otter"},
    {"name": "Harry", "house": "Gryffindor", "patronus": "stag"},
    {"name": "Draco", "house": "Slytherin", "patronus": None}
]
for student in students:
    print(student["name"], student["house"], sep=", ")
# Out:
# Hermione, Gryffindor
# Harry, Gryffindor
# Draco, Slytherin

# %%
def main():
    print_square(3)

def print_square(size):
    for i in range(size):
        for j in range(size):
            print("#", end="")

        print()
            

main()
# Out:
# ###
# ###
# ###

# %%
"hello Mike".find("Mike")
# Out:
# 6
